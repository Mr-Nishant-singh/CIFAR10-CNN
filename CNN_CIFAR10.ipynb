# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train,Y_train),(X_test,Y_test)=keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
X_train=np.array(X_train)/255
X_test=np.array(X_test)/255

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
model=keras.Sequential([
    Conv2D(32,(3,3),input_shape=(32,32,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    Conv2D(64,(3,3),activation='relu'),
    Flatten(),
    Dense(256,activation='relu'),
    Dense(10,activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 72s 45ms/step - loss: 1.5371 - accuracy: 0.4299
# Epoch 2/10
# 1563/1563 [==============================] - 68s 43ms/step - loss: 1.1622 - accuracy: 0.5842
# Epoch 3/10
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.0010 - accuracy: 0.6450
# Epoch 4/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.8928 - accuracy: 0.6827
# Epoch 5/10
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.8212 - accuracy: 0.7102
# Epoch 6/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.7534 - accuracy: 0.7310
# Epoch 7/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.6956 - accuracy: 0.7541
# Epoch 8/10
# 1563/1563 [==============================] - 62s 40ms/step - loss: 0.6463 - accuracy: 0.7719
# Epoch 9/10
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.5951 - accuracy: 0.7885
# Epoch 10/10
# ...

# %%
model.evaluate(X_test,Y_test)
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9184 - accuracy: 0.7126
# [0.9184366464614868, 0.7125999927520752]

# %%
model.save("CNN_CIFAR10_7126_8014.h5")
from google.colab import drive
drive.mount('/content/drive')
model.save('/content/drive/My Drive/CNN_CIFAR10_7126_8014.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Mounted at /content/drive

# %%
# prompt: save model as "CNN_CIFAR10_7126" om google drive

# !cp CNN_CIFAR10_7126 "/content/drive/MyDrive/"
# Out:
# cp: -r not specified; omitting directory 'CNN_CIFAR10_7126'
